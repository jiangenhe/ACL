# %%
import pandas as pd

# %%
df = pd.read_parquet("acl-publication-info.74k.parquet")

# %%
df.shape
# Out:
# (73285, 21)

# %%
df.head()
# Out:
#      acl_id                                           abstract  \
# 0  O02-2002  There is a need to measure word similarity whe...
# 1  L02-1310
# 2  R13-1042  Thread disentanglement is the task of separati...
# 3  W05-0819  In this paper, we describe a word alignment al...
# 4  L02-1309
#
#                                            full_text  corpus_paper_id  \
# 0  There is a need to measure word similarity whe...         18022704
# 1                                                             8220988
# 2  Thread disentanglement is the task of separati...         16703040
# 3  In this paper, we describe a word alignment al...          1215281
# 4                                                            18078432
#
#                                    pdf_hash  numcitedby  \
# 0  0b09178ac8d17a92f16140365363d8df88c757d0          14
# 1  8d5e31610bc82c2abc86bc20ceba684c97e66024          93
# 2  3eb736b17a5acb583b9a9bd99837427753632cdb          10
# ...

# %%
import matplotlib.pyplot as plt
# Count the number of articles per year
year_counts = df['year'].value_counts().sort_index()

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(year_counts.index, year_counts.values)

# Customize the chart
plt.title('Number of Articles by Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['acl_id', 'abstract', 'full_text', 'corpus_paper_id', 'pdf_hash',
#        'numcitedby', 'url', 'publisher', 'address', 'year', 'month',
#        'booktitle', 'author', 'title', 'pages', 'doi', 'number', 'volume',
#        'journal', 'editor', 'isbn'],
#       dtype='object')

# %%
# Count the number of articles per booktitle and get top 20
booktitle_counts = df['booktitle'].value_counts().head(20)

# Create a bar chart
plt.figure(figsize=(15, 8))
plt.bar(range(len(booktitle_counts)), booktitle_counts.values)

# Customize the chart
plt.title('Top 20 Publication Venues by Number of Articles')
plt.xlabel('Publication Venue')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add booktitle labels
plt.xticks(range(len(booktitle_counts)), booktitle_counts.index, rotation=45, ha='right')

# Adjust layout to prevent label cutoff
plt.tight_layout()
plt.show()
# Out:
# /var/folders/7q/x430d89s56v2bfb5x83w14640000gq/T/ipykernel_99648/653599633.py:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Count the number of articles per booktitle and get top 20
booktitle_counts = df['journal'].value_counts().head(20)

# Create a bar chart
plt.figure(figsize=(15, 8))
plt.bar(range(len(booktitle_counts)), booktitle_counts.values)

# Customize the chart
plt.title('Journal by Number of Articles')
plt.xlabel('Publication Venue')
plt.ylabel('Number of Articles')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add booktitle labels
plt.xticks(range(len(booktitle_counts)), booktitle_counts.index, rotation=45, ha='right')

# Adjust layout to prevent label cutoff
plt.tight_layout()
plt.show()
